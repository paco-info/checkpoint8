# %%
# Import des librairies nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering, KMeans
from scipy.cluster.hierarchy import dendrogram

# Chargement des données
data = pd.read_csv('CC GENERAL.csv')
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
# Suppression de la variable CUST_ID (non nécessaire pour la segmentation)
data.drop(['CUST_ID'], axis=1, inplace=True)

# Traitement des valeurs manquantes
data.fillna(method='ffill', inplace=True)

# Clustering hiérarchique
hc = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
hc.fit(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#       1 # Suppression de la variable CUST_ID (non nécessaire pour la segmentation)
# ----> 2 data.drop(['CUST_ID'], axis=1, inplace=True)
#       4 # Traitement des valeurs manquantes
#       5 data.fillna(method='ffill', inplace=True)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# Visualisation des clusters
plt.scatter(data.iloc[:,0], data.iloc[:,1], c=hc.labels_, cmap='rainbow')
plt.title('Clustering hiérarchique')
plt.xlabel('Balance')
plt.ylabel('Purchases')
plt.show()

# %%
# Construction du dendrogramme
plt.figure(figsize=(10, 7))
plt.title("Dendrogramme hiérarchique")
dendrogram(linkage(data, method='ward'))
plt.show()

# %%
# K-means clustering
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(data)
    sse.append(kmeans.inertia_)

# %%
# Recherche du nombre optimal de clusters
plt.plot(range(1, 11), sse)
plt.title('Méthode du coude')
plt.xlabel('Nombre de clusters')
plt.ylabel('SSE')
plt.show()

# %%
# Clustering K-means avec k=4 (nombre optimal de clusters)
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(data)

# %%
# Visualisation des clusters
plt.scatter(data.iloc[:,0], data.iloc[:,1], c=pred_y, cmap='rainbow')
plt.title('Clustering K-means')
plt.xlabel('Balance')
plt.ylabel('Purchases')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 # Visualisation des clusters
# ----> 2 plt.scatter(data.iloc[:,0], data.iloc[:,1], c=pred_y, cmap='rainbow')
#       3 plt.title('Clustering K-means')
#       4 plt.xlabel('Balance')
#
# NameError: name 'data' is not defined
